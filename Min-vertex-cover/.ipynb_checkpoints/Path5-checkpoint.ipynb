# %%
import Min_vertex_cover as mvc
import networkx as nx
import rustworkx as rx

import pennylane as qml
from pennylane.wires import Wires
from pennylane import numpy as np
from pennylane import qaoa
import tensorflow as tf

# %%
edges = [(0, 1), (1, 2),(2, 3),(3,4)]
graph = nx.Graph(edges)

nx.draw(graph, with_labels=True)

# %%
def qaoa_layer(gamma, beta):
    qaoa.cost_layer(gamma, cost_h)
    qaoa.mixer_layer(beta, mixer_h)
wires = range(5)
depth = 1

def circuit(params, **kwargs):
    for w in wires:
        qml.PauliX(wires=w)
    qml.layer(qaoa_layer, depth, params[0],params[1])

dev = qml.device("default.qubit", wires=wires)

@qml.qnode(dev)
def cost_function(params):
    circuit(params)
    return qml.expval(cost_h)

# %%
def exp_values(cost_h,mixer_h):
    bet   = np.arange(0,2*np.pi,0.01)
    gam   = np.linspace(1,1,np.size(bet))
    res   = []
    for i in range(np.size(bet)):
        params = np.array([[gam[i]],[bet[i]]])
        res   += [cost_function(params)]
    return res

# %%
cost_h = mvc.cost_h(graph,1)
print(cost_h)
# Out:
#   (-1) [Z0]
# + (-1) [Z1]
# + (-1) [Z2]
# + (-1) [Z3]
# + (-1) [Z4]

# %%
cost_h = mvc.cost_h(graph,1)

mixer_h_1 = mvc.bit_flip_mixer(graph,1)
mixer_h = mixer_h_1
exp_value_1 = exp_values(cost_h,mixer_h_1)

# %%
mixer_h_2 = mvc.bit_flip_mixer_2(graph,1)
mixer_h = mixer_h_2
exp_value_2 = exp_values(cost_h,mixer_h_2)

# %%
mixer_h_3 = mvc.bit_flip_mixer_3(graph,1)
mixer_h = mixer_h_3
exp_value_3 = exp_values(cost_h,mixer_h_3)

# %%
import matplotlib.pyplot as plt
bet   = np.arange(0,2*np.pi,0.01)
plt.plot(bet,c)
plt.plot(bet,d)
plt.plot(bet,e)
plt.plot(bet,np.linspace(np.mean(c),np.mean(c),np.size(bet)))
plt.plot(bet,np.linspace(np.mean(d),np.mean(d),np.size(bet)))
plt.plot(bet,np.linspace(np.mean(d),np.mean(d),np.size(bet)))

# %%
c = []
for a in exp_value_1:
    c += [a.numpy()]
c = np.array(c)
c = c/2+2.5

# %%
d = []
for b in exp_value_2:
    d +=[b.numpy()]
    
d = np.array(d)
d = d/2 + 2.5

# %%
e = []
for b in exp_value_3:
    e +=[b.numpy()]
    
e = np.array(e)
e = e/2 + 2.5

# %%
np.mean(c)
# Out:
# tensor(3.36505451, requires_grad=True)

# %%
np.mean(e)
# Out:
# tensor(3.595034, requires_grad=True)

# %%
np.mean(d)
# Out:
# tensor(3.40952382, requires_grad=True)

# %%
np.min(c)
# Out:
# tensor(2.0000019, requires_grad=True)

# %%
np.min(d)
# Out:
# tensor(2.00000571, requires_grad=True)

# %%
np.min(e)
# Out:
# tensor(3.0000019, requires_grad=True)
